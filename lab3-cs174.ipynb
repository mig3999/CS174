# %% [markdown]
# ## COMSC 174 Lab 3 -- String Operations

# %% [markdown]
# ### Question 1
#
# Write some python code that does the following:
#
# Create a string variable called `first` that contains "Row"
# Create a string variable called `second` that contains "Your Boat"
# Create a third string variable called `third` that contains "Gently down the stream."
#
# Now combine these strings using concatenation, so that they make sense.

# %%
# Question 1 answer

# %% [markdown]
# &nbsp;
#
# ### Question 2
#
# Extend the code above to include the second part of "Row, Row, Row your boat."

# %%
# Question 2 goes in here

# %% [markdown]
# &nbsp;
#
# ### Question 3
#
# Add to the code above (copy and paste is your friend) by putting all the concatenations above into one big string variable.  Then find the length of that variable and display it.

# %% [markdown]
# &nbsp;
#
# ### Question 4
#
# Write a program that prints the following grid to play tic-tac-toe.
# ```
# +--+--+--+
# |  |  |  |
# +--+--+--+
# |  |  |  |
# +--+--+--+
# |  |  |  |
# +--+--+--+
# ```
#
# Accomplish this task by creating string variables that are no more than 3 characters long, then using the repetition operator (`*`) to repeat the string variables as needed to display the grid.

# %%
# Question 4

# %% [markdown]
# &nbsp;
#
# ### Question 5
#
# Write the following mathematical expressions in Python:
#
# ![Screenshot 2024-01-22 at 6.18.10 pm.png](attachment:e7ede7ed-641a-421b-92da-d284a2c1d6b0.png)

# %%
# Question 5

# %% [markdown]
# &nbsp;
#
# ### Question 6
#
# Using string variables and their indexes to find individual characters, convert the following sentences so that they are written backwards (ie: the last character in the sentence is first, the second-last character is second, and so on).
#
# * I like Keyano College
# * Manchester City is under investigation
# * A man, a plan, panama!

# %% [markdown]
# &nbsp;
#
# ### Question 7
#
# Using Python, strings, lengths and some math, create variable with a long string, and then *center* that string like this:
#
# ```
# @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# -                                          -
# -        My name is Inigo Montoya          -
# -                                          -
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# ```
