# %% [markdown]
# ![Screenshot 2024-03-25 at 8.29.02 PM.png](attachment:ac4883d8-b10c-4e72-9370-c117b5204ac7.png)
#
# ### Lab 9 -- Lists

# %% [markdown]
# ## Question P6.1:
#
# Write a program that initializes a list with ten random integers and then prints four lines of output, containing:
#
# * Every element at  an  even index.
# * Every even element.
# * All  elements  in  reverse  order.
# * Only the first and last element.

# %%
# P6.1 in here

# %% [markdown]
# &nbsp;
#
# ## Question P6.2
#
# Write a program that reads numbers and adds them to a list if they aren’t already contained in the list. When the list contains ten numbers, the program displays the contents and quits.

# %%
# P6.2 goes here

# %% [markdown]
# &nbsp;
#
# ## Question P6.3
#
# Write a program that adds all numbers from 2 to 10,000 to a list. Then remove the multiples of 2 (but not 2), multiples of 3 (but not 3), and so on, up to the multiples of 100. Print the remaining values.

# %%
# P6.3 in here

# %% [markdown]
# &nbsp;
#
# ## Question P6.5
#
# Modify the program in Section P6.3 to mark both the smallest and the largest elements.

# %%
# P6.5 in here

# %% [markdown]
# &nbsp;
#
# ## Question P6.8
#
# Compute the alternating sum of all elements in a list. For example, if your program reads the input:
# ```
# 1 4 9 16 9 7 4 9 11
# ```
# then it computes:
# ```
# 1 – 4 + 9 – 16 + 9 – 7 + 4 – 9 + 11 = –2
# ```

# %%
# P6.8 in here

# %% [markdown]
# &nbsp;
#
# ## Question P6.9
#
# Write a function that reverses the sequence of elements in a list. For example, if you call the function with the list:
# ```
# 1 4 9 16 9 7 4 9 11
# ```
# then the list is changed to:
# ```
# 11 9 4 7 9 16 9 4 1
# ```

# %%
# P6.9 goes here

# %% [markdown]
# &nbsp;
#
# &nbsp;
#
# ### Press Play on the following block to see if youtube works inside a Jupyter Notebook

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/8ksr4oBpfqs" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
